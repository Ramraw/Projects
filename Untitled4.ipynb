# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramraw/Projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math,os
import random
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stat
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets
from sklearn.decomposition import PCA

iris = pd.read_csv('/content/Iris.csv')
iris_feat = iris.iloc[:,:-1]
iris_species = iris.iloc[:,-1]

# %%
iris_feat.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')

# %%
plt.scatter(x = iris_feat['SepalLengthCm'],y = [iris_feat['PetalLengthCm']],alpha=1)
plt.title('Scatter Plot')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
sns.scatterplot(data=iris_feat, x="SepalLengthCm", y="PetalLengthCm")

plt.title('Scatter Plot')
plt.xlabel('sepal_length')
plt.ylabel('petal_length') 
# Show the plot
plt.show()

# %%
df = pd.DataFrame({
    'A': [1,3,2,7,9,6,8,10],
    'B': [2,4,1,8,10,3,11,12],
    'C': ['a','a','a','a','b','b','b','b']
})

sns.lineplot(
    data=df,
    x="A", y="B", hue="C",style="C",
    markers=True, dashes=False
)

# %%
fig, ax = plt.subplots()
ax.hist(iris_feat['SepalLengthCm'])
ax.set_title('SepalLengthCm')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
N = 50
x = np.random.normal(200, 20, N)
y = x + np.random.normal(5, 25, N)
area = (40 * np.random.rand(N))**2
df = pd.DataFrame({
    'X': x,
    'Y': y,
    "size":area})
plt.scatter('X', 'Y', s='size',alpha=0.5, data=df)

plt.title('Title')
plt.xlabel('X axis')
plt.ylabel('Y axis') 

plt.show()

# %%
students = ['A','B','C','D','E'] 
scores = [30,40,50,10,5] 

plt.pie(scores, explode=[0,0.1,0,0,0], labels = students,colors = ['#EF8FFF','#ff6347','#B0E0E6','#7B68EE','#483D8B'])
plt.show()

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue="Species")

# %%
sns.violinplot(x="Species", y="PetalLengthCm", data=iris, size=6)

# %%
import plotly.figure_factory as ff

X = np.random.rand(15, 10)
fig = ff.create_dendrogram(X, color_threshold=1.5)
fig.update_layout(width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
